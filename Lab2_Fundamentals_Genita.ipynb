# %%
#cell 1
# CONFIG 
ENGINEER = "Genita"
STUDENT_ID = "TUPM-25-3534"

# DERIVATION
SEED_NUM = int(STUDENT_ID[-1])

print(f"System Initialized for: {ENGINEER}")
print(f"Algorithm Seed Value: {SEED_NUM}")
# Out:
# System Initialized for: Genita
# Algorithm Seed Value: 4

# %%
# ARCHITECTURE TEST
#LOGIC IF COMP AGREE NA 0.1+0.2=0.3

actual = 0.1 + 0.2
print(f"Python Stores: {actual}")

if actual == 0.3:
    print("Result: Perfect Match")
else:
    print("Result: Precision Error (Binary Artifact)")
# Out:
# Python Stores: 0.30000000000000004
# Result: Precision Error (Binary Artifact)

# %%
# CELL 3 ASCII INSPECTION
first_letter = ENGINEER[0]
byte_val = ord(first_letter) # eto raw to convert the characters into integer mem code

print(f"Character: {first_letter}")
print(f"ASCII Value: {byte_val}")
print(f"Next in sequence: {chr(byte_val+ 1)}")
# Out:
# Character: G
# ASCII Value: 71
# Next in sequence: H

# %%
# CELL 4 Sanitization

raw_in = input("Enter Name (     ): ")
#pipeline strip daw  white space to convert to uppercase
clean_in = raw_in.strip().upper()
print(f"Original: '{raw_in}' | Cleaned: '{clean_in}'")
# Out:
# Original: 'Genita' | Cleaned: 'GENITA'

# %%
# CELL 5 DATA EXISTENCE
user_input = input("Press enter () or type data")

#pythonic way an empty string is treated as false
if user_input:
    print(f"Data Detected: {user_input}")
else:
    print("ALERT: no data stream detected.")
# Out:
# ALERT: no data stream detected.

# %%
#cell 6 slicing and parsing
campus = STUDENT_ID[0:4]
unique_id = STUDENT_ID[8:]

#Tokenization pag split ng string into a list based on delimiter

tokens = STUDENT_ID.split("-")

print(f"Campus Code : {campus}")
print(f"Unique Sequence: {unique_id}")
print(f"Token list: {tokens}")
# Out:
# Campus Code : TUPM
# Unique Sequence: 3534
# Token list: ['TUPM', '25', '3534']

# %%
# cell 7 modulo operator

# logic to see if seed number is even or odd using modulo

if SEED_NUM % 2 == 0:
    priority = "LOW (Even seed)"
else:
    priority = "HIGH (Odd seed)"
print(f"System Priority: {priority}")
# Out:
# System Priority: LOW (Even seed)

# %%
#cell 8 dynamic limits

limit = (SEED_NUM * 10) + 20
print(f"---SAFETY LIMIT: {limit} ---")

val = int(input("Enter Sensor Reading: "))

if val > limit:
    print("ALERT: Over limit")
elif val < 5:
    print("ALERT: Low signal")
else:
    print("STATUS: Nominal")
# Out:
# ---SAFETY LIMIT: 60 ---
# ALERT: Low signal

# %%
# cell 9 robust input 
try:
    #convert input to integer
    voltage = int(input("Enter Voltage (Numeric): "))
    print(f"Voltage Captured: {voltage}V")
except ValueError:
    # occurs when typing words strings instead of int
    print("SYSTEM ERROR: INPUT MUST BE NUMERIC. RESETTING TO 0.")
    voltage = 0
print(f"SYSTEM CONTINUES... Current  Voltage: {voltage}")
# Out:
# Voltage Captured: 12V
# SYSTEM CONTINUES... Current  Voltage: 12

# %%
#cell 10 logic gates
has_power = False

if has_power and (10/0 == 0):
    print("System On")
else:
    print("System Off (Short Circuit Triggered)")
# Out:
# System Off (Short Circuit Triggered)

# %%
#cell 11 for loop
loops = SEED_NUM + 3
print(f"--- RUNNING {loops} CYCLES ---")

for i in range(1, loops + 1):
    print(f"cycle {i}/{loops}... Complete")
# Out:
# --- RUNNING 7 CYCLES ---
# cycle 1/7... Complete
# cycle 2/7... Complete
# cycle 3/7... Complete
# cycle 4/7... Complete
# cycle 5/7... Complete
# cycle 6/7... Complete
# cycle 7/7... Complete

# %%
#cell 12
# first digit of unique id determines rows

rows = int(tokens[2][0])
# last num determines col

cols = int(tokens[2][-1])
print(f"Generating {rows}x{cols} Matrix: ")

for r in range(rows):
    for c in range(cols):
        print("#", end=" ")
    print()
# Out:
# Generating 3x4 Matrix:
# # # # #
# # # # #
# # # # #

# %%
#cell 13 input validation

while True:
    pwd = input("Type: 'ADMIN' to exit: ")
    if pwd == "ADMIN":
        print("Unlocked")
        break
    else:
        print("ACCESS DENIED")
# Out:
# ACCESS DENIED
# ACCESS DENIED
# Unlocked

# %%
#CELL 14 FORENSIC HASH CALCULATION

A = byte_val
B = SEED_NUM
C = loops

verification_hash = (A*B)-C

print(f"user: {ENGINEER}")
print(f"Forensic Signature: {verification_hash}")
# Out:
# user: Genita
# Forensic Signature: 277
